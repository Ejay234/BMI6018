# %%
# Ejay Aguirre
# October 13, 2024
# Assignment: Debugging

# %%
'''
1.a
Using the print() function only, get the wrong_add_function to print out where
it is making a mistake, given the expected output for ex, "we are making an error 
in the loop", which you would put near the loop. 
Structure the print() statement to show what the expected output ought to be
via f-strings: ie "The correct answer is supposed to be: [...]".
1.b
Then, changing as little as possible, modify the function, using the same 
general structure to output the correct answer. Call this new function 
correct_add_function() 
'''
def wrong_add_function(arg1,arg2):
   '''
   The function takes in two lists of integers, then it adds
   all of arg2 to each item of arg1.
   
   Example:
      > wrong_add_function([1,2,3],[1,1,1])
      > [6,9,12]

   whereas the expected correct answer is, [2,3,4]

   Parameters
   ----------
   arg1 : list
      list of integers.
   arg2 : list
      list of integers.

   Returns
   -------
   arg1 : list
      Elements of arg1, with each element having had the contents of 
      arg2 added to it.

   '''
   arg1_index=0
   while arg1_index < len(arg1):
      arg_2_sum = 0
      print(f"Currently adding all elements in arg2 to arg1[{arg1_index}]")
      for arg2_elements in arg2:
         arg_2_sum = sum([arg1[arg1_index]+i for i in arg2])
         print(f"We are making an error in the loop. The incorrect sum is: {arg_2_sum}")
         print(f"The correct answer is supposed to be: {arg1[arg1_index] + sum(arg2)}")
      arg1[arg1_index]=arg_2_sum  
      arg1_index+=1
   print("we are making an error")
   return arg1

arg1 = [1,2,3]
arg2 = [1,1,1]

wrong_add_function(arg1, arg2)

def correct_add_function(arg1, arg2):
    '''
    The function takes in two lists of integers, then it adds
    the sum of all elements in arg2 to each item of arg1.
    '''
    arg1_index = 0
    arg_2_sum = sum(arg2)  
    while arg1_index < len(arg1):
        arg1[arg1_index] += arg_2_sum
        print(f"The correct sum for arg1[{arg1_index}] is: {arg1[arg1_index]}")
        arg1_index += 1
    return arg1

arg1 = [1, 2, 3]
arg2 = [1, 1, 1]
print(correct_add_function(arg1, arg2))
# Out:
# Currently adding all elements in arg2 to arg1[0]
# We are making an error in the loop. The incorrect sum is: 6
# The correct answer is supposed to be: 4
# We are making an error in the loop. The incorrect sum is: 6
# The correct answer is supposed to be: 4
# We are making an error in the loop. The incorrect sum is: 6
# The correct answer is supposed to be: 4
# Currently adding all elements in arg2 to arg1[1]
# We are making an error in the loop. The incorrect sum is: 9
# The correct answer is supposed to be: 5
# We are making an error in the loop. The incorrect sum is: 9
# The correct answer is supposed to be: 5
# We are making an error in the loop. The incorrect sum is: 9
# The correct answer is supposed to be: 5
# Currently adding all elements in arg2 to arg1[2]
# We are making an error in the loop. The incorrect sum is: 12
# The correct answer is supposed to be: 6
# We are making an error in the loop. The incorrect sum is: 12
# The correct answer is supposed to be: 6
# We are making an error in the loop. The incorrect sum is: 12
# The correct answer is supposed to be: 6
# we are making an error
# The correct sum for arg1[0] is: 4
# The correct sum for arg1[1] is: 5
# The correct sum for arg1[2] is: 6
# [4, 5, 6]

# %%
'''
2.a
Update the numeric section of the function with your changes from 1 for both 
2.b and 2.c

2.b
Without modifying the string section code itself or the input directly, 
write a try, except block that catches the issue with the input below and 
returns an error message to the user, in case users give invalid inputs,
(for example an input of ["5","2", 5])
: "Your input argument [1 or 2] at element [n]
is not of the expected type. Please change this and rerun. Name this function 
exception_add_function()

2.c
Without modifying the string section code itself or the input directly, 
write a try, except block that catches the issue with the input below and 
gets it to process via the string section. IE, do not, outside the function,
change the values of arg_str_1 or arg_str_2. Name this function 
correction_add_function(), i.e you will not be updating the wrong_add_function,
you will simply handle the error of wrong inputs in a seperate function, you want
the wrong_add_function to output its current result you are only bolstering the 
function for edge cases .
'''
def wrong_add_function(arg1,arg2):
    '''
    The function takes in two lists of integers, then it adds
    all of arg2 to each item of arg1.

    Example:
    > wrong_add_function([1,2,3],[1,1,1])
    > [4,5,6]

    If the lists are lists of strings, concatenate them
    Example:
    > wrong_add_function(['1','2','3'],['1','1','1'])
    > ['1111','2111','3111']
    Parameters
    ----------
    arg1 : list
    list of integers.
    arg2 : list
    list of integers.

    Returns
    -------
    arg1 : list
    Elements of arg1, with each element having had the contents of 
    arg2 added to it.

    '''
    #numeric section
    if sum([type(i) == int for i in arg1]) == len(arg1) and \
       sum([type(i) == int for i in arg2]) == len(arg2):
        arg1_index=0
        arg_2_sum = sum(arg2)
        while arg1_index < len(arg1):
            arg1[arg1_index] += arg_2_sum  
            arg1_index+=1
        return arg1
    
    #string section
    elif sum([type(i) == str for i in arg1]) == len(arg1) and \
         sum([type(i) == str for i in arg2]) == len(arg2):
        arg1_index = 0
        while arg1_index < len(arg1):
            arg_2_sum = ''
            for arg2_elements in arg2:
                arg_2_sum += arg2_elements
            arg1[arg1_index]=arg1[arg1_index]+str(arg_2_sum)
            arg1_index+=1
        return arg1

arg_str_1=['1','2','3']
arg_str_2=['1','1', 1]

print(wrong_add_function(arg_str_1,arg_str_2))

def exception_add_function(arg1, arg2):
    try:
        return correct_add_function(arg1, arg2)
    except TypeError as e:
        for i, val in enumerate(arg1):
            if not isinstance(val, (str)):
                return f"Your input argument 1 at element {i} is not of the expected type. Please change this and rerun."
        for i, val in enumerate(arg2):
            if not isinstance(val, (str)):
                return f"Your input argument 2 at element {i} is not of the expected type. Please change this and rerun."
        return f"An unexpected error occured: {str(e)}"

arg_str_1=['1','2','3']
arg_str_2=['1','1', 1]

print(exception_add_function(arg_str_1, arg_str_2))

def correction_add_function(arg1, arg2):
    try:
        arg1_str = [str(item) if isinstance(item, int) else item for item in arg1]
        arg2_str = [str(item) if isinstance(item, int) else item for item in arg2]
        return wrong_add_function(arg1_str, arg2_str)
    except Exception as e:
        return f"An error occurred: {str(e)}"
    
arg_str_1=['1','2','3']
arg_str_2=['1','1', 1]
print(correction_add_function(arg_str_1,arg_str_2))
# Out:
# None
# Your input argument 2 at element 2 is not of the expected type. Please change this and rerun.
# ['1111', '2111', '3111']
